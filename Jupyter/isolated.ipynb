# %%
# %%configure -f
# {"name": "isolated_test", "driverMemory": "2G"}
# Out:
# Current session configs: <tt>{'driverMemory': '2G', 'name': 'isolated_test', 'kind': 'pyspark'}</tt><br>

# %%
sc.version
# Out:
# Kernel Id: 59c12c31-8292-4712-9f2f-e4766ebc74cd
# Starting Spark application
# <table>
# ...

# %%
sc.applicationId
# Out:
# <div class="progress-ipython-shell"></div>
# 'application_1581484612169_0001'
